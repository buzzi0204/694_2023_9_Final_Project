# %%
from pymongo import MongoClient
import json

# %%
#Connecting to database 
try:
    conn = MongoClient()
    print("Connected successfully")
except:  
    print("Could not connect to MongoDB")
  
# database
db = conn.database
collection = db.tweets_data
# Out:
# Connected successfully

# %%
with open("json_files/sample_json_file.json", "r") as f:
    data = json.load(f)

# %%
keys = ['id', 'id_str', 'text', 'created_at', 'entities', 'retweet_count', 'favorite_count', 'lang']

# %%
if 'retweeted_status' in index.keys():
    print("dfen")
# Out:
# dfen

# %%
index['retweeted_status']
# Out:
# {'created_at': 'Sun Apr 12 13:19:18 +0000 2020',
#  'id': 1249326224964345857,
#  'id_str': '1249326224964345857',
#  'text': 'Thank You Sir !!\nReally thankful for encouraging the \n@BSNL_OR \n Staff risking their life in maintaining the Teleco… https://t.co/4Qq4QZEqUP',
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'truncated': True,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 268218622,
#   'id_str': '268218622',
#   'name': 'Umesh Agrawal',
#   'screen_name': 'umesh_agr',
#   'location': None,
#   'url': None,
#   'description': None,
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 288,
#   'friends_count': 322,
#   'listed_count': 0,
#   'favourites_count': 127,
#   'statuses_count': 258,
#   'created_at': 'Fri Mar 18 10:53:11 +0000 2011',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1185088546387836928/NzRMDHWo_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1185088546387836928/NzRMDHWo_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/268218622/1571382105',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'quoted_status_id': 1249319407177744385,
#  'quoted_status_id_str': '1249319407177744385',
#  'quoted_status': {'created_at': 'Sun Apr 12 12:52:12 +0000 2020',
#   'id': 1249319407177744385,
#   'id_str': '1249319407177744385',
#   'text': 'Thanked our PSUs, especially PSUs from oil, gas, steel and @eastcoastrail, @BSNL_OR, @NHAI_Official, @NALCO_India,… https://t.co/owP6fYQvBX',
#   'display_text_range': [0, 140],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1897514666,
#    'id_str': '1897514666',
#    'name': 'Dharmendra Pradhan',
#    'screen_name': 'dpradhanbjp',
#    'location': 'Delhi/Odisha/India',
#    'url': 'http://dpradhanbjp.com',
#    'description': 'Minister of Petroleum & Natural Gas and Minister of Steel, Government of India. Views personal. RTs not endorsement',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 1209645,
#    'friends_count': 1660,
#    'listed_count': 854,
#    'favourites_count': 8542,
#    'statuses_count': 39050,
#    'created_at': 'Mon Sep 23 14:45:38 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '89C9FA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '89C9FA',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1200790882661752832/H738N-4M_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1200790882661752832/H738N-4M_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1897514666/1585497285',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'Thanked our PSUs, especially PSUs from oil, gas, steel and @eastcoastrail, @BSNL_OR, @NHAI_Official, @NALCO_India, @ntpclimited, @AAI_Official, @mahanadicoal, @paradipport, @IndiaPostOffice, @pgcilindia for their dedicated efforts in strengthening the fight against corona. https://t.co/ThsGJRrg0W',
#    'display_text_range': [0, 273],
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'eastcoastrail',
#       'name': 'EAST COAST Railway',
#       'id': 3017315815,
#       'id_str': '3017315815',
#       'indices': [59, 73]},
#      {'screen_name': 'BSNL_OR',
#       'name': 'BSNL_Odisha',
#       'id': 756765832584294400,
#       'id_str': '756765832584294400',
#       'indices': [75, 83]},
#      {'screen_name': 'NHAI_Official',
#       'name': 'NHAI',
#       'id': 903136272935297025,
#       'id_str': '903136272935297025',
#       'indices': [85, 99]},
#      {'screen_name': 'NALCO_India',
#       'name': 'NALCO',
#       'id': 781386619773411328,
#       'id_str': '781386619773411328',
#       'indices': [101, 113]},
#      {'screen_name': 'ntpclimited',
#       'name': 'NTPC Limited',
#       'id': 511697512,
#       'id_str': '511697512',
#       'indices': [115, 127]},
#      {'screen_name': 'AAI_Official',
#       'name': 'Airports Authority of India',
#       'id': 877832878830137345,
#       'id_str': '877832878830137345',
#       'indices': [129, 142]},
#      {'screen_name': 'mahanadicoal',
#       'name': 'Mahanadi Coalfields Limited',
#       'id': 730998952900730882,
#       'id_str': '730998952900730882',
#       'indices': [144, 157]},
#      {'screen_name': 'paradipport',
#       'name': 'Paradip Port Trust',
#       'id': 3282083100,
#       'id_str': '3282083100',
#       'indices': [159, 171]},
#      {'screen_name': 'IndiaPostOffice',
#       'name': 'India Post',
#       'id': 2579558348,
#       'id_str': '2579558348',
#       'indices': [173, 189]},
#      {'screen_name': 'pgcilindia',
#       'name': 'POWERGRID',
#       'id': 4915722482,
#       'id_str': '4915722482',
#       'indices': [191, 202]}],
#     'symbols': [],
#     'media': [{'id': 1249319378916499457,
#       'id_str': '1249319378916499457',
#       'indices': [274, 297],
#       'media_url': 'http://pbs.twimg.com/media/EVZ5Wx9UYAE2W0-.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EVZ5Wx9UYAE2W0-.jpg',
#       'url': 'https://t.co/ThsGJRrg0W',
#       'display_url': 'pic.twitter.com/ThsGJRrg0W',
#       'expanded_url': 'https://twitter.com/dpradhanbjp/status/1249319407177744385/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 709, 'h': 572, 'resize': 'fit'},
#        'medium': {'w': 709, 'h': 572, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 549, 'resize': 'fit'}}},
#      {'id': 1249319378916528128,
#       'id_str': '1249319378916528128',
#       'indices': [274, 297],
#       'media_url': 'http://pbs.twimg.com/media/EVZ5Wx9U0AAKAHT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EVZ5Wx9U0AAKAHT.jpg',
#       'url': 'https://t.co/ThsGJRrg0W',
#       'display_url': 'pic.twitter.com/ThsGJRrg0W',
#       'expanded_url': 'https://twitter.com/dpradhanbjp/status/1249319407177744385/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1024, 'h': 604, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 604, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 401, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1249319378916499457,
#       'id_str': '1249319378916499457',
#       'indices': [274, 297],
#       'media_url': 'http://pbs.twimg.com/media/EVZ5Wx9UYAE2W0-.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EVZ5Wx9UYAE2W0-.jpg',
#       'url': 'https://t.co/ThsGJRrg0W',
#       'display_url': 'pic.twitter.com/ThsGJRrg0W',
#       'expanded_url': 'https://twitter.com/dpradhanbjp/status/1249319407177744385/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 709, 'h': 572, 'resize': 'fit'},
#        'medium': {'w': 709, 'h': 572, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 549, 'resize': 'fit'}}},
#      {'id': 1249319378916528128,
#       'id_str': '1249319378916528128',
#       'indices': [274, 297],
#       'media_url': 'http://pbs.twimg.com/media/EVZ5Wx9U0AAKAHT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EVZ5Wx9U0AAKAHT.jpg',
#       'url': 'https://t.co/ThsGJRrg0W',
#       'display_url': 'pic.twitter.com/ThsGJRrg0W',
#       'expanded_url': 'https://twitter.com/dpradhanbjp/status/1249319407177744385/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1024, 'h': 604, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 604, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 401, 'resize': 'fit'}}}]}},
#   'quote_count': 30,
#   'reply_count': 53,
#   'retweet_count': 200,
#   'favorite_count': 410,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/owP6fYQvBX',
#      'expanded_url': 'https://twitter.com/i/web/status/1249319407177744385',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}],
#    'user_mentions': [{'screen_name': 'eastcoastrail',
#      'name': 'EAST COAST Railway',
#      'id': 3017315815,
#      'id_str': '3017315815',
#      'indices': [59, 73]},
#     {'screen_name': 'BSNL_OR',
#      'name': 'BSNL_Odisha',
#      'id': 756765832584294400,
#      'id_str': '756765832584294400',
#      'indices': [75, 83]},
#     {'screen_name': 'NHAI_Official',
#      'name': 'NHAI',
#      'id': 903136272935297025,
#      'id_str': '903136272935297025',
#      'indices': [85, 99]},
#     {'screen_name': 'NALCO_India',
#      'name': 'NALCO',
#      'id': 781386619773411328,
#      'id_str': '781386619773411328',
#      'indices': [101, 113]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'quoted_status_permalink': {'url': 'https://t.co/kulXd1yTtC',
#   'expanded': 'https://twitter.com/dpradhanbjp/status/1249319407177744385',
#   'display': 'twitter.com/dpradhanbjp/st…'},
#  'is_quote_status': True,
#  'extended_tweet': {'full_text': 'Thank You Sir !!\nReally thankful for encouraging the \n@BSNL_OR \n Staff risking their life in maintaining the Telecom Services so that people can stay home &amp; work from home too.\n#BSNL Odisha is doing great job.🙏🙏',
#   'display_text_range': [0, 215],
#   'entities': {'hashtags': [{'text': 'BSNL', 'indices': [181, 186]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'BSNL_OR',
#      'name': 'BSNL_Odisha',
#      'id': 756765832584294400,
#      'id_str': '756765832584294400',
#      'indices': [54, 62]}],
#    'symbols': []}},
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 18,
#  'favorite_count': 24,
#  'entities': {'hashtags': [],
#   'urls': [{'url': 'https://t.co/4Qq4QZEqUP',
#     'expanded_url': 'https://twitter.com/i/web/status/1249326224964345857',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}],
#   'user_mentions': [{'screen_name': 'BSNL_OR',
#     'name': 'BSNL_Odisha',
#     'id': 756765832584294400,
#     'id_str': '756765832584294400',
#     'indices': [54, 62]}],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'filter_level': 'low',
#  'lang': 'en'}

# %%
def mongo_insertor(index, keys):
    obj = {}
    for key in keys:
        obj[key] = index[key]
    obj['user_id'] = index['user']['id']
    return obj


for index in data:
    if 'retweeted_status' in index.keys():
        obj = mongo_insertor(index['retweeted_status'], keys)
        collection.insert_one(obj)
        
    if 'quoted_status' in index.keys():
        obj = mongo_insertor(index['quoted_status'], keys)
        collection.insert_one(obj)
    
    
    obj = mongo_insertor(index, keys)
    collection.insert_one(obj)
